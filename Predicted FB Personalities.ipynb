# %%
import pymongo
import pandas as pd
import pickle
from data_prep import DataPrep
from model import Model
from sklearn.preprocessing import MinMaxScaler

# %%
mc = pymongo.MongoClient()
db = mc['my-facebook-webscrape']
fb_statuses = db['fb-statuses']

# %%
def anonymize_name(name):
    output = ""
    for i in name.split():
        output += i[0] + '.'
    return output

# %%
names_and_statuses = list(fb_statuses.find({'friends_dict': {'$exists': False}}, {'statuses':1, 'name':1, '_id':0}))

df_dict = {'NAME': [], 'DATE': [], 'STATUS': []}
for entry in names_and_statuses:
    
    name = entry['name']
#     name = anonymize_name(name)
    
    statuses = entry['statuses']
    
    for date, status in statuses.items():
        df_dict['NAME'].append(name)
        df_dict['DATE'].append(date)
        df_dict['STATUS'].append(status)

df = pd.DataFrame(df_dict)
df['STATUS_COUNT'] = df.groupby("NAME")["STATUS"].transform('count')

# %%
df
# Out:
#                     DATE             NAME  \
# 0      08/03/2009 9:20pm  Kellian Valenti
# 1      08/02/2010 4:32am  Kellian Valenti
# 2      08/03/2010 4:19am  Kellian Valenti
# 3     05/03/2018 12:17pm         Chen Chi
# 4      04/14/2018 4:03pm         Chen Chi
# 5      04/13/2018 9:48am         Chen Chi
# 6      03/03/2018 9:22pm         Chen Chi
# 7     02/20/2018 12:41pm         Chen Chi
# 8      01/12/2018 7:18pm         Chen Chi
# 9      01/12/2018 7:11pm         Chen Chi
# 10    01/11/2018 12:47pm         Chen Chi
# 11     01/08/2018 5:26pm         Chen Chi
# 12     01/02/2018 7:43am         Chen Chi
# 13     12/25/2017 2:07pm         Chen Chi
# 14     12/03/2017 3:31pm         Chen Chi
# 15     10/28/2017 5:04pm         Chen Chi
# 16     10/28/2017 7:16am         Chen Chi
# 17     10/26/2017 7:53am         Chen Chi
# 18     10/23/2017 5:10am         Chen Chi
# 19     10/16/2017 6:10pm         Chen Chi
# 20     10/10/2017 6:22am         Chen Chi
# 21    10/02/2017 11:55am         Chen Chi
# 22    10/02/2017 11:54am         Chen Chi
# 23     10/01/2017 4:39pm         Chen Chi
# 24     09/30/2017 5:47pm         Chen Chi
# 25     09/27/2017 7:28am         Chen Chi
# 26     09/25/2017 3:48pm         Chen Chi
# 27    09/25/2017 12:57pm         Chen Chi
# 28     09/25/2017 6:55am         Chen Chi
# 29     09/21/2017 7:10am         Chen Chi
# ...                  ...              ...
# 7870   06/21/2015 3:50am       Sijing Qiu
# 7871   05/23/2015 3:03pm       Sijing Qiu
# 7872   05/23/2015 6:55am       Sijing Qiu
# 7873   05/16/2015 1:50am       Sijing Qiu
# 7874   05/13/2015 9:41am       Sijing Qiu
# 7875   05/13/2015 9:04am       Sijing Qiu
# 7876   01/18/2018 3:51pm   Chase Morimoto
# 7877   06/29/2017 5:59pm   Chase Morimoto
# 7878  06/11/2017 10:41pm   Chase Morimoto
# 7879   03/24/2017 8:24am   Chase Morimoto
# 7880   01/18/2017 1:12am   Chase Morimoto
# 7881   01/16/2017 8:50pm   Chase Morimoto
# 7882   01/15/2017 1:14am   Chase Morimoto
# 7881  A cool project two of my old highschool friend...            24
# 7882  Was too focused on finals week/apps that i lef...            24
# 7883                   Why must you torment me spotify             24
# 7884   After 3 months I have a working cellphone again             24
# 7885  This speaks to me more than ever during finals...            24
# 7886    These samurai don't kill; they clean up trash.             24
# 7887  Still my favorite band after 10 years :,) Ladi...            24
# 7888  Throwback to that one time my car keys got lit...            24
# 7889     Best way to end the weekend❤️ Hawaii -> Japan             24
# 7890  Excited to finally leave for my summer abroad ...            24
# 7891  We should have trained Kolo when he was younge...            24
# 7892       I'm not crying you're crying F.R.I.E.N.D.S.             24
# 7893                           A typical Friday night.             24
# 7894                                          haha aww             24
# 7895  For those of you in Seattle, I will be startin...            24
# 7896  Hello, Dear Ones. Please enjoy our new video f...            24
# 7897  this was four years ago.... I got a creative f...            24
# 7898  Thank you everyone for the birthday wishes! It...            24
# 7899  HAPPY BIRTHDAY CHASE! Wahhh this creepy pikach...            24
#
# [7900 rows x 4 columns]

# %%
traits = ['OPN', 'CON', 'EXT', 'AGR', 'NEU']

for trait in traits:
    pkl_model = pickle.load(open(trait + '_model.pkl', "rb"))
    dp = DataPrep()
    X = df['STATUS']
    
    trait_scores = pkl_model.predict(X, regression=True)
    df['pred_s'+trait] = trait_scores
    
    trait_categories = pkl_model.predict(X, regression=False)
    df['pred_c'+trait] = trait_categories
    
    trait_categories_probs = pkl_model.predict_proba(X)
    df['pred_prob_c'+trait] = trait_categories_probs[:, 1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-376-d150e5a082b5> in <module>()
#       6     X = df['STATUS']
#       7
# ----> 8     trait_scores = pkl_model.predict(X, regression=True)
#       9     df['pred_s'+trait] = trait_scores
#      10
#
# ~/galvanize/Capstone/model.py in predict(self, X, regression)
#      24         X = self.tfidf.transform(X)
#      25         if regression:
# ---> 26             return self.rfr.predict(X)
#      27         else:
#      28             return self.rfc.predict(X)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     694         Parallel(n_jobs=n_jobs, verbose=self.verbose, backend="threading")(
#     695             delayed(accumulate_prediction)(e.predict, X, [y_hat], lock)
# --> 696             for e in self.estimators_)
#     697
#     698         y_hat /= len(self.estimators_)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in accumulate_prediction(predict, X, out, lock)
#     381
#     382 def accumulate_prediction(predict, X, out, lock):
# --> 383     prediction = predict(X, check_input=False)
#     384     with lock:
#     385         if len(out) == 1:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in predict(self, X, check_input)
#     411         check_is_fitted(self, 'tree_')
#     412         X = self._validate_X_predict(X, check_input)
# --> 413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#     415
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/sparse/base.py in get_shape(self)
#      98         self._shape = shape
#      99
# --> 100     def get_shape(self):
#     101         """Get shape of a matrix."""
#     102         return self._shape
#
# KeyboardInterrupt:

# %%
df['STATUS']
# Out:
# 0                                 I'm done (╯°□°）╯︵ ┻━┻)
# 1                                                 Summer
# 2                                                 Summer
# 3       Kind of healing especially in these tough days...
# 4                    A rainy week -_-\nDimmed ocean view
# 5             I'm fine\nSmiley face:) @ Downtown Seattle
# 6             I'm fine\nSmiley face:) @ Downtown Seattle
# 7       想去的地方终于打了卡，相聚离开都有时候，但我们都走在一条叫做努力的路上.See u when...
# 8                                       Amazing Samsung~
# 9                        油腻少女范儿get! @ Chelsea, Manhattan
# 10                       油腻少女范儿get! @ Chelsea, Manhattan
# 11                                                  板栗烧鸡
# 12      May we be at peace.\nBegin New Year with stand...
# 13                             和每一个角落说一个不够正式的再见 再见再见再见再见
# 14                             和每一个角落说一个不够正式的再见 再见再见再见再见
# 15                   Sunset on Hudson River\n对港口，船只，蜜汁热爱
# 16                   Sunset on Hudson River\n对港口，船只，蜜汁热爱
# 17                 Σ(●ꉺ▱ꉺ●)\n写代码时候找到内心的平静\n可惜离专业水准早已相去甚远
# 18                            New York metropolitan area
# 19                            New York metropolitan area
# 20                  这大概也是比较开心的事情了\nA source of happiness
# 21      What's small and furry and scurries through th...
# 22      What's small and furry and scurries through th...
# 23      What's small and furry and scurries through th...
# 24                                       美食博主和手工。。月饼？的合影
# 25      This AI managed to predict which start-ups wou...
# 26                                          给我不吃的花生找个了下家
# 27                                          给我不吃的花生找个了下家
# 28                                          给我不吃的花生找个了下家
# 29                                          给我不吃的花生找个了下家
#                               ...
# 7870                          最爱我的爸爸！Happy father's day!
# 7871                          最爱我的爸爸！Happy father's day!
# 7872                         New hair, don't careeee ❤️💇
# 7873                         New hair, don't careeee ❤️💇
# 7874    The Naval Academy is deeply saddened to report...
# 7875    The Naval Academy is deeply saddened to report...
# 7876    Thank you to everyone for the awesome bday wis...
# 7877    Time for a new prof pic so people don't think ...
# 7878                                         all done :D
# 7879                                    New Gorillaz :,)
# 7880             Thank you everyone for the bday wishes!
# 7881    A cool project two of my old highschool friend...
# 7882    Was too focused on finals week/apps that i lef...
# 7883                     Why must you torment me spotify
# 7884     After 3 months I have a working cellphone again
# 7885    This speaks to me more than ever during finals...
# 7886      These samurai don't kill; they clean up trash.
# 7887    Still my favorite band after 10 years :,) Ladi...
# 7888    Throwback to that one time my car keys got lit...
# 7889       Best way to end the weekend❤️ Hawaii -> Japan
# 7890    Excited to finally leave for my summer abroad ...
# 7891    We should have trained Kolo when he was younge...
# 7892         I'm not crying you're crying F.R.I.E.N.D.S.
# 7893                             A typical Friday night.
# 7894                                            haha aww
# 7895    For those of you in Seattle, I will be startin...
# 7896    Hello, Dear Ones. Please enjoy our new video f...
# 7897    this was four years ago.... I got a creative f...
# 7898    Thank you everyone for the birthday wishes! It...
# 7899    HAPPY BIRTHDAY CHASE! Wahhh this creepy pikach...
# Name: STATUS, Length: 7900, dtype: object

# %%
trait_categories = []
trait_categories_probabilities = []
trait_scores = [
'pred_sOPN', 'pred_sCON', 'pred_sEXT', 'pred_sAGR', 'pred_sNEU',
]
trait_categories_scores_percentiles = []

# %%
scaler = MinMaxScaler(feature_range=(0, 50))
scores = df[trait_scores]
scaled_scores = scaler.fit_transform(scores)

df_scaled = pd.DataFrame(scaled_scores)
df_scaled.columns = trait_scores
df_scaled

# 7899   01/17/2016 6:44pm   Chase Morimoto
#
#                                                  STATUS  STATUS_COUNT  \
# 0                               I'm done (╯°□°）╯︵ ┻━┻)              3
# 1                                               Summer              3
# 2                                               Summer              3
# 3     Kind of healing especially in these tough days...            94
# 4                  A rainy week -_-\nDimmed ocean view             94
# 5           I'm fine\nSmiley face:) @ Downtown Seattle             94
# 6           I'm fine\nSmiley face:) @ Downtown Seattle             94
# 7     想去的地方终于打了卡，相聚离开都有时候，但我们都走在一条叫做努力的路上.See u when...            94
# 8                                     Amazing Samsung~             94
# 9                      油腻少女范儿get! @ Chelsea, Manhattan             94
# 10                     油腻少女范儿get! @ Chelsea, Manhattan             94
# 11                                                板栗烧鸡             94
# 12    May we be at peace.\nBegin New Year with stand...            94
# 13                           和每一个角落说一个不够正式的再见 再见再见再见再见             94
# 14                           和每一个角落说一个不够正式的再见 再见再见再见再见             94
# 15                 Sunset on Hudson River\n对港口，船只，蜜汁热爱             94
# 16                 Sunset on Hudson River\n对港口，船只，蜜汁热爱             94
# 17               Σ(●ꉺ▱ꉺ●)\n写代码时候找到内心的平静\n可惜离专业水准早已相去甚远             94
# 18                          New York metropolitan area             94
# 19                          New York metropolitan area             94
# 20                这大概也是比较开心的事情了\nA source of happiness             94
# 21    What's small and furry and scurries through th...            94
# 22    What's small and furry and scurries through th...            94
# 23    What's small and furry and scurries through th...            94
# 24                                     美食博主和手工。。月饼？的合影             94
# 25    This AI managed to predict which start-ups wou...            94
# 26                                        给我不吃的花生找个了下家             94
# 27                                        给我不吃的花生找个了下家             94
# 28                                        给我不吃的花生找个了下家             94
# 29                                        给我不吃的花生找个了下家             94
# ...                                                 ...           ...
# 7870                        最爱我的爸爸！Happy father's day!            104
# 7871                        最爱我的爸爸！Happy father's day!            104
# 7872                       New hair, don't careeee ❤️💇            104
# 7873                       New hair, don't careeee ❤️💇            104
# 7874  The Naval Academy is deeply saddened to report...           104
# 7875  The Naval Academy is deeply saddened to report...           104
# 7876  Thank you to everyone for the awesome bday wis...            24
# 7877  Time for a new prof pic so people don't think ...            24
# 7878                                       all done :D             24
# 7879                                  New Gorillaz :,)             24
# 7880           Thank you everyone for the bday wishes!             24
# 7881  A cool project two of my old highschool friend...            24
# 7882  Was too focused on finals week/apps that i lef...            24
# 7883                   Why must you torment me spotify             24
# 7884   After 3 months I have a working cellphone again             24
# 7885  This speaks to me more than ever during finals...            24
# 7886    These samurai don't kill; they clean up trash.             24
# 7887  Still my favorite band after 10 years :,) Ladi...            24
# 7888  Throwback to that one time my car keys got lit...            24
# 7889     Best way to end the weekend❤️ Hawaii -> Japan             24
# 7890  Excited to finally leave for my summer abroad ...            24
# 7891  We should have trained Kolo when he was younge...            24
# 7892       I'm not crying you're crying F.R.I.E.N.D.S.             24
# 7893                           A typical Friday night.             24
# 7894                                          haha aww             24
# 7895  For those of you in Seattle, I will be startin...            24
# 7896  Hello, Dear Ones. Please enjoy our new video f...            24
# 7897  this was four years ago.... I got a creative f...            24
# 7896       True        0.558569  15.758762      False        0.136364
# 7897      False        0.443981  22.776393      False        0.494240
# 7898       True        0.775736  11.097665      False        0.127273
# 7899      False        0.463636  17.808202      False        0.381818
#
# [7900 rows x 19 columns]

# %%
df_mean_scores = df.groupby('NAME')[[
    'pred_sOPN', 'pred_sCON', 'pred_sEXT', 'pred_sAGR', 'pred_sNEU',
]].mean()

df_mean_scores['status_counts'] = df.groupby('NAME')['STATUS_COUNT'].count()

df_mean_scores.sort_values(by=['status_counts'], ascending=False)
# Out:
#                         pred_sOPN  pred_sCON  pred_sEXT  pred_sAGR  pred_sNEU  \
# NAME
# Stanley Cheng           32.135479  27.376874  30.418839  27.827454  17.608064
# Emmanuel Watkins        32.193403  26.643276  29.272339  25.898633  19.380555
# Kimberli Cheung Wright  33.037520  28.075634  30.000318  27.884735  17.792256
# Eddie Ignacio           32.182786  27.134386  28.543318  26.571175  19.488914
# Bradley Li              32.904767  26.892076  28.862625  27.377663  18.245517
# William Young           32.280717  26.353868  29.145153  25.903751  20.278178
# Annelise Yee            32.428381  27.076602  29.918682  27.222200  18.765195
# Rosanna Cheng           32.650958  27.269315  29.888626  27.070168  18.229877
# Nick DeJesus            31.993604  25.820168  29.015642  26.164273  19.784358
# Jonathan Cheung         31.904739  27.432580  29.993243  27.174066  18.840942
# Elliott Crane           33.019133  27.012240  28.908526  28.473297  17.824838
# Barryn Chun             32.992875  26.944062  28.660416  26.572953  19.222954
# Christophus Mohammed    32.482385  29.402734  29.366997  27.068110  18.388933
# Adam Koehler            32.591609  27.458961  29.110811  26.307567  20.425737
# Ani Izuta               31.204789  25.953438  30.185695  26.581247  19.212954
# Rui Stitch              32.119550  26.918610  28.847401  26.667699  18.692985
# Sijing Qiu              31.912734  28.132891  30.130955  27.406681  17.330185
# Brandon Low             31.923371  28.138343  29.316019  27.768098  18.440487
# KoDee Dink              33.273045  26.666786  29.600336  26.490210  19.082277
# Chris Lee               32.580344  27.390207  28.487272  25.806195  19.594951
# Miles Mackenzie         31.913741  26.868043  29.526453  26.546966  19.738722
# Phill Kelsey            32.314675  27.035304  29.737793  27.761972  18.137488
# Jun Soo Shin            32.096434  28.327590  29.092292  24.502679  20.873386
# Gunho Ed Yun            32.049803  27.190861  29.061742  24.176023  21.518792
# Alexander Hooton        32.268170  26.518781  29.244092  25.773789  18.263259
# Jin Ahn                 32.354002  28.555226  29.203687  26.524487  18.341433
# Jesse Stafford          31.362602  27.363695  29.198648  26.148063  18.851501
# Carli Matsuoka          31.331511  27.892829  30.850660  28.981246  16.888975
# Jonnie Kashiro          31.901367  27.146177  29.095568  26.370495  19.971532
# Jermyia Blevins         32.569829  24.070178  28.074324  26.583156  19.200373
# ...                           ...        ...        ...        ...        ...
# Jenna Marie Shintaku    29.707182  20.393424  26.749439  25.200812  20.230575
# Lian Moss               39.142993  27.741911  30.873373  35.501308  10.000277
# Jean-Pierre Bourquin    32.827534  28.661681  35.147143  26.544950  18.300787
# Alex Keeno              32.082555  27.823069  27.200280  24.282429  20.981335
# Cara Mukai                          1
# Chase Tamashiro                     1
# Marcus Yoshii                       1
# Sarah Moore                         1
# Sho Tetsutani                       1
# Ricky Cheng                         1
# Kayla Tinkleberry                   1
# Nicholas Kawasaki                   1
# Amy Li                              1
# Darren Leiman                       1
# Steven Pugh                         1
# Davin Tsubota                       1
# Kaci Uyehara                        1
# Bryce Leggett                       1
# Chad Kamisugi                       1
# Rashelle Nagata                     1
#
# [373 rows x 6 columns]

# %%
df_mean_scores = df.groupby('NAME')[[
    'pred_sOPN', 'pred_sCON', 'pred_sEXT', 'pred_sAGR', 'pred_sNEU',
]].mean()

df_mean_scores = df.groupby(['NAME'], as_index=False).agg(
                      {'pred_sOPN':['mean'], 'pred_sCON':['mean'], 'pred_sEXT':['mean'], 'pred_sAGR':['mean'], 'pred_sNEU':['mean']})

df_mean_scores.columns = ['NAME', 'avg_pred_sOPN', 'avg_pred_sCON', 'avg_pred_sEXT', 'avg_pred_sAGR', 'avg_pred_sNEU']

df = df.merge(df_mean_scores, how='right', on='NAME')

# %%
df_mean_scores = df.groupby('NAME')[[
    'pred_prob_cOPN', 'pred_prob_cCON', 'pred_prob_cEXT', 'pred_prob_cAGR', 'pred_prob_cNEU'
]].median()

df_mean_scores['status_counts'] = df.groupby('NAME')['STATUS_COUNT'].count()

df_mean_scores.sort_values(by=['status_counts'], ascending=False)
# Out:
#                         pred_prob_cOPN  pred_prob_cCON  pred_prob_cEXT  \
# NAME
# Stanley Cheng                 0.791092        0.462953        0.390909
# Emmanuel Watkins              0.695140        0.451479        0.366726
# Kimberli Cheung Wright        0.773593        0.448980        0.380220
# Eddie Ignacio                 0.727041        0.436364        0.366726
# Bradley Li                    0.770942        0.445455        0.366726
# William Young                 0.759258        0.418182        0.370526
# Annelise Yee                  0.781818        0.451479        0.409420
# Rosanna Cheng                 0.790505        0.445455        0.366726
# Nick DeJesus                  0.745455        0.414398        0.366726
# Jonathan Cheung               0.761515        0.441335        0.390909
# Elliott Crane                 0.766739        0.490909        0.415152
# Barryn Chun                   0.806294        0.419091        0.347727
# Christophus Mohammed          0.776111        0.472727        0.365181
# Adam Koehler                  0.736364        0.451479        0.366726
# Ani Izuta                     0.680632        0.451479        0.366726
# Rui Stitch                    0.740909        0.451479        0.366726
# Sijing Qiu                    0.770418        0.444335        0.413304
# Brandon Low                   0.781818        0.451479        0.366726
# KoDee Dink                    0.779198        0.445455        0.363636
# Chris Lee                     0.761558        0.430514        0.378531
# Miles Mackenzie               0.781943        0.443651        0.366726
# Phill Kelsey                  0.773552        0.451479        0.372727
# Jun Soo Shin                  0.680632        0.451479        0.366726
# Gunho Ed Yun                  0.680632        0.451479        0.366726
# Alexander Hooton              0.702285        0.451479        0.366726
# Jin Ahn                       0.790909        0.481818        0.393753
# Jesse Stafford                0.688749        0.475096        0.397656
# Carli Matsuoka                0.781818        0.490909        0.409091
# Jonnie Kashiro                0.685710        0.447583        0.351145
# Jermyia Blevins               0.785455        0.409091        0.363636
# ...                                ...             ...             ...
# Lian Moss                     0.448764        0.247047              1
# Jean-Pierre Bourquin          0.519033        0.380324              1
# Alex Keeno                    0.422867        0.460993              1
# Joey Marvi                    0.767273        0.468485              1
# Owen Harrelson                0.472125        0.100000              1
# James Sykes                   0.744924        0.244978              1
# Itinually Impressed           0.536364        0.236364              1
# Patrick Sheehan               0.548122        0.275504              1
# Nigel Ng                      0.218182        0.909091              1
# Brooke Naomi                  0.827273        0.063636              1
# Elliot Fan                    0.509091        0.354545              1
# Amy Qiting Luo-Xu             0.681818        0.122460              1
# Chandler Teruya               0.501202        0.462381              1
# Cara Mukai                    0.709091        0.105540              1
# Chase Tamashiro               0.245108        0.785379              1
# Marcus Yoshii                 0.296752        0.519573              1
# Sarah Moore                   0.616561        0.211868              1
# Sho Tetsutani                 0.563636        0.418182              1
# Ricky Cheng                   0.741667        0.155270              1
# Kayla Tinkleberry             0.367698        0.569208              1
# Nicholas Kawasaki             0.420443        0.465721              1
# Amy Li                        0.420443        0.465721              1
# Darren Leiman                 0.583528        0.188745              1
# Steven Pugh                   0.636364        0.236364              1
# Davin Tsubota                 0.341740        0.331624              1
# Kaci Uyehara                  0.627273        0.495308              1
# Bryce Leggett                 0.681818        0.127273              1
# Chad Kamisugi                 0.712500        0.172727              1
# Rashelle Nagata               0.890909        0.213939              1
#
# [373 rows x 6 columns]

# %%
# df_mean_scores = df.groupby('NAME')[[
#     'pred_cOPN', 'pred_cCON', 'pred_cEXT', 'pred_cAGR', 'pred_cNEU',
# ]].count()

# df_mean_scores['status_counts'] = df.groupby('NAME')['STATUS_COUNT'].count()

# df_mean_scores.sort_values(by=['status_counts'], ascending=False)

# %%
possible_percentiles = list(range(101))
    
def calc_percentile(score, pop_scores):
    score_percentiles = []
    
    for perc in possible_percentiles:
        score_percentiles.append(np.percentile(pop_scores, perc))
        
    calc_perc = 0
    for score_perc, perc in zip(score_percentiles, possible_percentiles):
        if int(score_perc) >= score:
            calc_perc = perc
            break
        elif int(score_perc) > score:
            break
            
    return calc_perc

# %%
import scipy.stats as stats

df['sOPN_percentile'] = df['avg_pred_sOPN'].apply(lambda x: stats.percentileofscore(df['avg_pred_sOPN'].sort_values(),x))
df['sCON_percentile'] = df['avg_pred_sCON'].apply(lambda x: stats.percentileofscore(df['avg_pred_sCON'].sort_values(),x))
df['sEXT_percentile'] = df['avg_pred_sEXT'].apply(lambda x: stats.percentileofscore(df['avg_pred_sAGR'].sort_values(),x))
df['sAGR_percentile'] = df['avg_pred_sAGR'].apply(lambda x: stats.percentileofscore(df['avg_pred_sEXT'].sort_values(),x))
df['sNEU_percentile'] = df['avg_pred_sNEU'].apply(lambda x: stats.percentileofscore(df['avg_pred_sNEU'].sort_values(),x))

# %%
df_mean_scores = df.groupby('NAME')[[
    'sOPN_percentile', 'sCON_percentile', 'sEXT_percentile', 'sAGR_percentile', 'sNEU_percentile',
]].mean()

df_mean_scores['status_counts'] = df.groupby('NAME')['STATUS_COUNT'].count()

df_mean_scores.sort_values(by=['status_counts'], ascending=False)
