# %%
import pandas as pd

# %%
test_sample = pd.read_csv('Personality_Traits_Testset_v1.csv')
pd.read_csv('random sample submission.csv')
# Out:
#       myID  machiavellianism  narcissim  openness  conscientiousness  \
# 0      433               419        231       426                650
# 1     2195               305        784       169                405
# 2     2360               430        829       759                336
# 3      140              1044        767        88                105
# 4     2464               795        287       412                147
# 5     2234               348         59       723                736
# 6       56               234        754       368               1122
# 7      878               461       1085       517                485
# 8     2062               436        632       514                804
# 9     2895               815        336       660                847
# 10     822               386        701       209                305
# 11     352                95       1129      1034                 61
# 12    1054               290         44       673                710
# ...
